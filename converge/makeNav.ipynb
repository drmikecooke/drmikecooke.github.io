# %%
import os

# find directories
thedir='.'
directories=[ name for name in os.listdir(thedir) if os.path.isdir(os.path.join(thedir, name)) ]

# find html files
menu=[]
for directory in directories:
    htmls=[html for html in os.listdir(directory) if html[-5:]=='.html']
    htmls.sort()
    if htmls!=[]:
        menu+=[[directory,htmls]]

# get menu data from htmls
from bs4 import BeautifulSoup as soup

def getItemData(dname,file):
    with open(f'{dname}/{file}') as fp:
        html = soup(fp, 'html.parser')
    if html.article.h1:
        project=html.article.h1.text
    if html.article.div:
        project=html.article.div.text
    return [project,f'{dname}/{file}',f'{file.split(".")[0]} — {html.h2.text}']

details=[]
for directory in menu:
    details+=[getItemData(directory[0],file) for file in directory[1]]

# group details
group={}
for item in details:
    if item[0] in group:
        group[item[0]]+=[item[1:]]
    else:
        group[item[0]]=[item[1:]]

# write new nav.js file and backup
from datetime import datetime

with open('nav.js','r') as nav:
    navlines=nav.readlines()
    
if not os.path.exists('bak'):
    os.makedirs('bak')

with open(f'bak/{int(datetime.timestamp(datetime.now()))}.js','w') as backup:
    backup.writelines(navlines)

navlines[0]=f"var menuItems = {str(group)}\n"

with open('nav.js','w') as newNav:
    newNav.writelines(navlines)
    
print('New menu ready!')
# Out:
# rooted 0.html
# 	 <div class="tag" id="tag">Rooted</div> None
# rooted 1.html
# 	 <div class="tag" id="tag">Rooted</div> None
# rooted 2.html
# 	 <div class="tag" id="tag">Rooted</div> None
# rooted 3.html
# 	 <div class="tag" id="tag">Rooted</div> None
# rooted 4.html
# 	 <div class="tag" id="tag">Rooted</div> None
# rooted 5.html
# 	 <div class="tag" id="tag">Rooted</div> None
# rooted 6.html
# 	 <div class="tag" id="tag">Rooted</div> None
# Euler-Maclaurin 0.html
# 	 <div class="tag" id="tag">Euler-Maclaurin</div> None
# Euler-Maclaurin 1.html
# 	 <div class="tag" id="tag">Euler-Maclaurin</div> None
# Euler-Maclaurin 2.html
# 	 <div class="tag" id="tag">Euler-Maclaurin</div> None
# Bernoulli 0.html
# 	 <div class="tag" id="tag">Bernoulli polynomials</div> None
# Bernoulli 1.html
# 	 <div class="tag" id="tag">Bernoulli polynomials</div> None
# Bernoulli 2.html
# 	 <div class="tag" id="tag">Bernoulli polynomials</div> None
# Bernoulli 3.html
# 	 <div id="tag">Bernoulli polynomials</div> None
# Bernoulli 4.html
# 	 <div id="tag">Bernoulli polynomials</div> None
# Bernoulli 4old.html
# 	 <div id="tag">Bernoulli polynomials 4´</div> None
# Bernoulli 5.html
# 	 <div id="tag">Bernoulli polynomials</div> None
# equivalence 0.html
# 	 <div class="tag" id="tag">Equivalence</div> None
# Gamma 0.html
# 	 None <h1 id="gamma-function">Gamma function</h1>
# Gamma 1.html
# 	 None <h1 id="gamma-function">Gamma function</h1>
# Gamma 2.html
# 	 None <h1 id="gamma-function">Gamma function</h1>
# Gamma 3.html
# 	 None <h1 id="gamma-function">Gamma function</h1>
# Gamma 4.html
# 	 None <h1 id="gamma-function">Gamma function</h1>
# Gamma 5.html
# 	 None <h1 id="gamma-function">Gamma function</h1>
# Gamma 6.html
# 	 None <h1 id="gamma-function">Gamma function</h1>
# Gamma 7.html
# 	 None <h1 id="gamma-function">Gamma function</h1>
# Gamma 8.html
# 	 None <h1 id="gamma-function">Gamma function</h1>
# New menu ready!
