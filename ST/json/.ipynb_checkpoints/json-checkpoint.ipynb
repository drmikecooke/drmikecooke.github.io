# %%
import json

def get(file):
    with open(file, 'r') as fp:
        return json.load(fp)

def put(d,file):
    with open(file, 'w') as fp:
        json.dump(d, fp)

def STitem(caption,img,url,ref):
    return {'caption':caption,'img':img,'url':url,'ref':ref}

def addSTitem(d,month,item):
    if month in d.keys():
        d[month] += [item]
    else:
        d = {month:[item],**d}
    return d

# %%
def inputST(d):
    month=input('Month: ')
    caption=input('Caption: ')
    img=input('Image: ')
    href=input('Link: ')
    ref=input('Reference: ')
    return addSTitem(d,month,STitem(caption,img,href,ref))

# %%
j=inputST(j)
# Out:
# Month:  December
# Caption:  Integrating indium gallium arsenide transistor and III-V laser on silicon
# Image:  2017/12/6.svg
# Link:  http://www.semiconductor-today.com/news_items/2018/jan/nus_100118.shtml
# Reference:  6 FET-LD integration on Si

# %%
j
# Out:
# {'December': [{'caption': 'Gallium nitride transistor on silicon with 250GHz cut-off frequency',
#    'img': '2017/12/1.jpg',
#    'url': 'http://www.semiconductor-today.com/news_items/2017/dec/ntu_071217.shtml',
#    'ref': '1 250GHz GaN on Si'},
#   {'caption': 'Monolithic III-nitride on silicon photonics for Internet of Things',
#    'img': '2017/12/2.jpg',
#    'url': 'http://www.semiconductor-today.com/news_items/2017/dec/nupt_131217.shtml',
#    'ref': '2 GaN on Si photonics'},
#   {'caption': 'Deep ultraviolet photonic crystal of aluminium gallium nitride nanowires',
#    'img': '2017/12/3.jpg',
#    'url': 'http://www.semiconductor-today.com/news_items/2017/dec/mcmasteruniversity_201217.shtml',
#    'ref': '3 DUV AlGaN nanowire LED'},
#   {'caption': 'III-nitride resonant tunneling diodes at room temperature and below',
#    'img': '2017/12/4.svg',
#    'url': 'http://www.semiconductor-today.com/news_items/2018/jan/cornell_020118.shtml',
#    'ref': '4 III-N RTDs'},
#   {'caption': 'Indium metal-catalysis of gallium oxide plasma molecular beam epitaxy',
#    'img': '2017/12/5.svg',
#    'url': 'http://www.semiconductor-today.com/news_items/2017/dec/pdiff_271217.shtml',
#    'ref': '5 Gallium oxide MBE'},
#   {'caption': 'Integrating indium gallium arsenide transistor and III-V laser on silicon',
#    'img': '2017/12/6.svg',
#    'url': 'http://www.semiconductor-today.com/news_items/2018/jan/nus_100118.shtml',
#    'ref': '6 FET-LD integration on Si'}],
#  'November': [{'caption': 'Reverse-blocking gallium nitride on silicon high-electron-mobility transistor',
#    'img': '2017/11/1.jpg',
#    'url': 'http://www.semiconductor-today.com/news_items/2017/nov/ecole_081117.shtml',
#    'ref': '1 GaN-on-Si RB-MOSHEMT'},
#   {'caption': 'Improving efficiency of V-band indium gallium nitride transistors and MMICs',
#    'img': '2017/11/2.svg',
#    'url': 'http://www.semiconductor-today.com/news_items/2017/nov/hrl_151117.shtml',
#    'ref': '2 V-band DHFET'},
#   {'caption': 'Monolithic indium arsenide quantum dots on silicon optoelectronics',
#    'img': '2017/11/3.jpg',
#    'url': 'http://www.semiconductor-today.com/news_items/2017/nov/ucsb_221117.shtml',
#    'ref': '3 InAs QDs on Si'},
#   {'caption': 'Ex-situ aluminium nitride on silicon templates for light-emitting diodes',
#    'img': '2017/11/4.webp',
#    'url': 'http://www.semiconductor-today.com/news_items/2017/nov/scut_291117.shtml',
#    'ref': '4 AlN-on-Si template for LEDs'},
#   {'caption': 'Reducing bow of indium gallium phosphide on silicon wafers',
#    'img': '2017/11/5.jpg',
#    'url': 'http://www.semiconductor-today.com/news_items/2017/dec/mit_011217.shtml',
#    'ref': '5 Reduced bow InGaP on Si'},
#   {'caption': 'Removing sapphire substrate from light-emitting diodes without cracking',
#    'img': '2017/11/6.jpg',
#    'url': 'http://www.semiconductor-today.com/news_items/2017/dec/fbi_041217.shtml',
#    'ref': '6 DUV LED LLO'}],
#  'October': [{'caption': 'Indium gallium nitride quantum dot microcavity light emission',
#    'img': '2017/10/1.jpg',
#    'url': 'http://www.semiconductor-today.com/news_items/2017/oct/sinano_111017.shtml',
#    'ref': '1 InGaN QD MC'},
#   {'caption': 'Low-threshold indium arsenide quantum dot laser diodes on silicon',
#    'img': '2017/10/2.jpg',
#    'url': 'http://www.semiconductor-today.com/news_items/2017/oct/ucsb_131017.shtml',
#    'ref': '2 InAs QD LDs'},
#   {'caption': 'Thermal curing of SU-8 for bonding gallium arsenide to silicon',
#    'img': '2017/10/3.webp',
#    'url': 'http://www.semiconductor-today.com/news_items/2017/oct/dominion_181017.shtml',
#    'ref': '3 GaAs Schottky diode'},
#   {'caption': 'Vertical gallium nitride Schottky diodes with single and double drift layers',
#    'img': '2017/10/4.jpg',
#    'url': 'http://www.semiconductor-today.com/news_items/2017/oct/asu_201017.shtml',
#    'ref': '4 GaN Schottky diode'},
#   {'caption': 'Vertical gallium nitride p-n diode with 5.0kV breakdown performance',
#    'img': '2017/10/5.jpg',
#    'url': 'http://www.semiconductor-today.com/news_items/2017/oct/hosei_251017.shtml',
#    'ref': '5 5kV GaN pn diode'},
#   {'caption': 'III-nitride on silicon optoelectronics transfer to plastic and glass',
#    'img': '2017/10/6.jpg',
#    'url': 'http://www.semiconductor-today.com/news_items/2017/nov/nanjing_011117.shtml',
#    'ref': '6 GaN on SI transfer'}],
#  'September': [{'caption': 'Aluminium nitride nanocolumns on gallium nitride templates',
#    'img': '2017/09/1.jpg',
#    'url': 'http://www.semiconductor-today.com/news_items/2017/sep/cnrs_060917.shtml',
#    'ref': '1 AlN nanocolumns'},
#   {'caption': 'Thinning p-type III-nitride layers to enhance effects of surface plasmons',
#    'img': '2017/09/2.jpg',
#    'url': 'http://www.semiconductor-today.com/news_items/2017/sep/ntu_130917.shtml',
#    'ref': '2 SP enhanced LEDs'},
#   {'caption': 'Aluminium gallium nitride transistors on silicon-on-insulator substrate',
#    'img': '2017/09/3.jpg',
#    'url': 'http://www.semiconductor-today.com/news_items/2017/sep/cgu_150917.shtml',
#    'ref': '3 MISHEMT on SOI'},
#   {'caption': 'Deep-ultraviolet gallium nitride quantum dots in aluminium nitride',
#    'img': '2017/09/4.jpg',
#    'url': 'http://www.semiconductor-today.com/news_items/2017/sep/cornell_270917.shtml',
#    'ref': '4 GaN QDs in AlN'},
#   {'caption': 'Reducing costs for gallium arsenide Schottky diode fabrication',
#    'img': '2017/09/5.jpg',
#    'url': 'http://www.semiconductor-today.com/news_items/2017/oct/sherbrooke_041017.shtml',
#    'ref': '5 GaAs Schottky diode fabrication'},
#   {'caption': 'Step-flow growth of green-emitting indium gallium nitride quantum wells',
#    'img': '2017/09/6.jpg',
#    'url': 'http://www.semiconductor-today.com/news_items/2017/oct/cas_061017.shtml',
#    'ref': '6 Step-flow green InGaN'}],
#  'August': [{'caption': 'Controlled spalling of bulk and free-standing gallium nitride substrates',
#    'img': '2017/08/1.jpg',
#    'url': 'http://www.semiconductor-today.com/news_items/2017/aug/ibm_140817.shtml',
#    'ref': '1 GaN spalling'},
#   {'caption': 'Indium gallium arsenide phosphide quantum wells on silicon on insulator',
#    'img': '2017/08/2.jpg',
#    'url': 'http://www.semiconductor-today.com/news_items/2017/aug/ucsb_160817.shtml',
#    'ref': '2 InGaAsP NWs on SOI'},
#   {'caption': 'Monolithic red-green-blue InGaN pixels from strain engineered nanopillars',
#    'img': '2017/08/3.webp',
#    'url': 'http://www.semiconductor-today.com/news_items/2017/aug/rgb_180817.shtml',
#    'ref': '3 monolithic RGB InGaN'},
#   {'caption': 'High-breakdown slanted tri-gate gallium nitride power transistors',
#    'img': '2017/08/4.jpg',
#    'url': 'http://www.semiconductor-today.com/news_items/2017/aug/epf_230817.shtml',
#    'ref': '4 Slanted tri-gate GaN MOSHEMT'},
#   {'caption': 'Gallium nitride on silicon in-plane gate field-effect transistors',
#    'img': '2017/08/5.webp',
#    'url': 'http://www.semiconductor-today.com/news_items/2017/aug/epf_300817.shtml',
#    'ref': '5 GaN IPGFET'},
#   {'caption': 'Silicon implantation for gallium nitride light-emitting diodes',
#    'img': '2017/08/6.webp',
#    'url': 'http://www.semiconductor-today.com/news_items/2017/sep/ncku_010917.shtml',
#    'ref': '6 Si implanted GaN LED'}],
#  'July': [{'caption': 'Amber quantum wells on indium gallium nitride pseudo-substrate',
#    'img': '2017/07/1.svg',
#    'url': 'http://www.semiconductor-today.com/news_items/2017/jul/grenoble_130717.shtml',
#    'ref': '1 InGaNOS pseudo-substrate'},
#   {'caption': 'High-voltage regrown vertical gallium nitride p-n diodes on bulk substrate',
#    'img': '2017/07/2.jpg',
#    'url': 'http://www.semiconductor-today.com/news_items/2017/jul/cornell_190717.shtml',
#    'ref': '2 1kV regrown GaN vertical diode'},
#   {'caption': 'Towards gallium nitride integration with silicon CMOS',
#    'img': '2017/07/3.jpg',
#    'url': 'http://www.semiconductor-today.com/news_items/2017/jul/veeco_260717.shtml',
#    'ref': '3 GaN on SOI'},
#   {'caption': 'Monolithic electrically injected microdisk lasers on silicon',
#    'img': '2017/07/4.jpg',
#    'url': 'http://www.semiconductor-today.com/news_items/2017/jul/ras_310717.shtml',
#    'ref': '4 microdisk on Si EL'},
#   {'caption': 'Aluminium nitride Schottky barrier diodes with breakdown more than 1kV',
#    'img': '2017/07/5.jpg',
#    'url': 'http://www.semiconductor-today.com/news_items/2017/aug/asu_020817.shtml',
#    'ref': '5 AlN SBD'},
#   {'caption': 'Near-ultraviolet laser diodes powering visible (white) light communication',
#    'img': '2017/07/6.jpg',
#    'url': 'http://www.semiconductor-today.com/news_items/2017/aug/usb_090817.shtml',
#    'ref': '6 NUV LD white VLC'}],
#  'June': [{'caption': 'Improving isolation of gallium nitride transistors on silicon-on-insulator',
#    'img': '2017/06/1.jpg',
#    'url': 'http://www.semiconductor-today.com/news_items/2017/jun/okmetic_070617.shtml',
#    'ref': '1 GaN on SOI'},
#   {'caption': 'Gallium nitride implanted current-aperture vertical electron transistor',
#    'img': '2017/06/2.webp',
#    'url': 'http://www.semiconductor-today.com/news_items/2017/jun/ucsb_200617.shtml',
#    'ref': '2 implanted CAVET'},
#   {'caption': 'Finding the root of nanopipes in aluminium nitride on sapphire',
#    'img': '2017/06/3.jpg',
#    'url': 'http://www.semiconductor-today.com/news_items/2017/jun/sandia_210617.shtml',
#    'ref': '3 nanopipes in AlN on sapphire'},
#   {'caption': 'Indium tin oxide metal-organic chemical vapor deposition for UV LEDs',
#    'img': '2017/06/4.webp',
#    'url': 'http://www.semiconductor-today.com/news_items/2017/jun/sysu_280617.shtml',
#    'ref': '4 UV ITO'},
#   {'caption': 'High-quality nitrogen-polar gallium nitride vertical p-n diodes',
#    'img': '2017/06/5.svg',
#    'url': 'http://www.semiconductor-today.com/news_items/2017/jun/cornell_300617.shtml',
#    'ref': '5 N-polar GaN diodes'},
#   {'caption': 'Smart stacking III-V on crystal silicon solar cells to boost conversion',
#    'img': '2017/06/6.svg',
#    'url': 'http://www.semiconductor-today.com/news_items/2017/jul/niaist_050717.shtml',
#    'ref': '6 III-V on c-Si smart stack'}],
#  'May': [{'caption': 'Ultraviolet photodetection with gallium nitride nanoflowers on silicon',
#    'img': '2017/05/1.jpg',
#    'url': 'http://www.semiconductor-today.com/news_items/2017/may/csir_050517.shtml',
#    'ref': '1 GaN NF PDs on silicon'},
#   {'caption': 'Indium gallium nitride solar cells on non-polar and semi-polar substrates',
#    'img': '2017/05/2.jpg',
#    'url': 'http://www.semiconductor-today.com/news_items/2017/may/asu_100517.shtml',
#    'ref': '2 Nonpolar InGaN solar cells'},
#   {'caption': 'Gallium oxide transistor radio-frequency measurements',
#    'img': '2017/05/3.svg',
#    'url': 'http://www.semiconductor-today.com/news_items/2017/may/afrl_120517.shtml',
#    'ref': '3 Ga2O3 RF transistor'},
#   {'caption': 'Indium gallium arsenide quantum well transistors on 300mm silicon',
#    'img': '2017/05/4.jpg',
#    'url': 'http://www.semiconductor-today.com/news_items/2017/may/knu_100517.shtml',
#    'ref': '4 InGaAs QW MOSFETs on 300m Si'},
#   {'caption': ' Indium gallium nitride light-emitting diodes on thin industry-spec silicon',
#    'img': '2017/05/5.jpg',
#    'url': 'http://www.semiconductor-today.com/news_items/2017/may/mit_190517.shtml',
#    'ref': '5 GaN on SEMI Si'},
#   {'caption': 'Toward visible and ultraviolet III-nitride lasers on silicon',
#    'img': '2017/05/6.svg',
#    'url': 'http://www.semiconductor-today.com/news_items/2017/may/inac_240517.shtml',
#    'ref': '6 III-nitride microlasers on Si'},
#   {'caption': 'Optimizing trench profiles for power gallium nitride electronic devices',
#    'img': '2017/05/7.jpg',
#    'url': 'http://www.semiconductor-today.com/news_items/2017/may/mit_260517.shtml',
#    'ref': '7 corner rounding'},
#   {'caption': 'Monolithic gallium antimonide-based laser diodes on silicon substrate',
#    'img': '2017/05/8.svg',
#    'url': 'http://www.semiconductor-today.com/news_items/2017/jun/udm_010617.shtml',
#    'ref': '8 GaSb on Si'}],
#  'April': [{'caption': 'Direct growth of III-V material on silicon for 1.55μm quantum dot lasers',
#    'img': '2017/04/1.jpg',
#    'url': 'http://www.semiconductor-today.com/news_items/2017/apr/hkust_060417.shtml',
#    'ref': '1 QD MDL on Si'},
#   {'caption': 'Fluorinated graphene passivation for aluminium gallium nitride transistors',
#    'img': '2017/04/2.jpg',
#    'url': 'http://www.semiconductor-today.com/news_items/2017/apr/shanghai_100417.shtml',
#    'ref': '2 FG AlGaN MIS-HEMT'},
#   {'caption': 'Gallium nitride fin transistor with high linearity and output power',
#    'img': '2017/04/3.jpg',
#    'url': 'http://www.semiconductor-today.com/news_items/2017/apr/nedi_070417.shtml',
#    'ref': '3 AlGaN finFET'},
#   {'caption': 'Improving vertical gallium nitride Schottky barrier diodes',
#    'img': '2017/04/4.png',
#    'url': 'http://www.semiconductor-today.com/news_items/2017/apr/nims_190417.shtml',
#    'ref': '4 improved GaN vertical SBD'},
#   {'caption': 'Alcohol-based digital etch on arsenide and antimonide III-V semiconductors',
#    'img': '2017/04/5.webp',
#    'url': 'http://www.semiconductor-today.com/news_items/2017/apr/mit_240417.shtml',
#    'ref': '5 alcohol digitial etch'},
#   {'caption': 'Buffer and drift layer effects on vertical gallium nitride diodes',
#    'img': '2017/04/6.jpg',
#    'url': 'http://www.semiconductor-today.com/news_items/2017/apr/asu_260417.shtml',
#    'ref': '6 vertical GaN diode buffer'},
#   {'caption': 'Monolithic gallium nitride vertical transistor and light-emitting diode',
#    'img': '2017/04/7.webp',
#    'url': 'http://www.semiconductor-today.com/news_items/2017/apr/hkust_280417.shtml',
#    'ref': '7 monolithic VMOSFET-LED'},
#   {'caption': 'Epitaxial lift-off and wafer bonding for III-V photodetectors on silicon',
#    'img': '2017/04/8.jpg',
#    'url': 'http://www.semiconductor-today.com/news_items/2017/may/kist_030517.shtml',
#    'ref': '8 ELO speed up'}],
#  'March': [{'caption': 'Gallium nitride vertical fin power field-effect transistors with 800V breakdown',
#    'img': '2017/03/1.svg',
#    'url': 'http://www.semiconductor-today.com/news_items/2017/mar/mit_100317.shtml',
#    'ref': '1 GaN power FinFET'},
#   {'caption': 'Growing quantum dot lasers on microelectronics-compatible silicon',
#    'img': '2017/03/2.jpg',
#    'url': 'http://www.semiconductor-today.com/news_items/2017/mar/ucl_150317.shtml',
#    'ref': '2 QD laser on silicon'},
#   {'caption': 'Gallium nitride vertical junction barrier Schottky diodes',
#    'img': '2017/03/3.svg',
#    'url': 'http://www.semiconductor-today.com/news_items/2017/mar/iqe_220317.shtml',
#    'ref': '3 vertical GaN JBSD'},
#   {'caption': 'Semi-polar indium gallium nitride laser diode/waveguide photodiode combo',
#    'img': '2017/03/4.webp',
#    'url': 'http://www.semiconductor-today.com/news_items/2017/mar/kaust_240317.shtml',
#    'ref': '4 LD-WPD semipolar InGaN'},
#   {'caption': 'Monolithic III-V transistors and laser diodes integrated on germanium',
#    'img': '2017/03/5.jpg',
#    'url': 'http://www.semiconductor-today.com/news_items/2017/mar/nus_290317.shtml',
#    'ref': '5 integrated FET-LD on Ge'},
#   {'caption': 'Non-polar gallium nitride ultraviolet photodetector on sapphire',
#    'img': '2017/03/6.webp',
#    'url': 'http://www.semiconductor-today.com/news_items/2017/mar/csir_300317.shtml',
#    'ref': '6 NP GaN UV detector'},
#   {'caption': 'Monolithic amber-green-blue nanopillar light-emitting diodes',
#    'img': '2017/03/7.jpg',
#    'url': 'http://www.semiconductor-today.com/news_items/2017/mar/michigan_310317.shtml',
#    'ref': '7 nanopillar amber-green-blue LEDs'},
#   {'caption': 'Direct hole injection plugs for indium gallium nitride light-emitting diodes',
#    'img': '2017/03/8.jpg',
#    'url': 'http://www.semiconductor-today.com/news_items/2017/apr/snu_050417.shtml',
#    'ref': '8 DHIP LEDs'}],
#  'February': [{'caption': 'N-polar gallium nitride gives record power density and efficiency at 94GHz',
#    'img': '2017/02/1.webp',
#    'url': 'http://www.semiconductor-today.com/news_items/2017/feb/ucsb_030217.shtml',
#    'ref': '1 94GHz MISHEMT'},
#   {'caption': 'Gallium nitride quantum dot emission at 232nm deep ultraviolet',
#    'img': '2017/02/2.webp',
#    'url': 'http://www.semiconductor-today.com/news_items/2017/feb/cornell_010217.shtml',
#    'ref': '2 deep UV LEDs'},
#   {'caption': 'Aluminium indium gallium nitride electron-blocking layers',
#    'img': '2017/02/3.jpg',
#    'url': 'http://www.semiconductor-today.com/news_items/2017/feb/scut_140217.shtml',
#    'ref': '3 blue GaN LED EBL'},
#   {'caption': 'Gallium nitride on silicon on insulator metal-organic vapor phase epitaxy',
#    'img': '2017/02/4.svg',
#    'url': 'http://www.semiconductor-today.com/news_items/2017/feb/aalto_150217.shtml',
#    'ref': '4 GaN on SOI'},
#   {'caption': 'Bulk aluminium nitride platform for gallium nitride high voltage and power',
#    'img': '2017/02/5.svg',
#    'url': 'http://www.semiconductor-today.com/news_items/2017/feb/cornell_200217.shtml',
#    'ref': '5 GaN QWFETs on bulk AlN'},
#   {'caption': 'Silicon and III-nitride high-voltage monolithic cascode diode',
#    'img': '2017/02/6.svg',
#    'url': 'http://www.semiconductor-today.com/news_items/2017/feb/hkust_220217.shtml',
#    'ref': '6 cascoded Si-GaN diode'},
#   {'caption': 'Improving indium arsenide antimonide nanowire optical quality on silicon',
#    'img': '2017/02/7.jpg',
#    'url': 'http://www.semiconductor-today.com/news_items/2017/mar/lancaster_020317.shtml',
#    'ref': '7 InAsSb nanowires on silicon'},
#   {'caption': 'Towards polarized white light with tunnel junctions and hybrid growth',
#    'img': '2017/02/8.jpg',
#    'url': 'http://www.semiconductor-today.com/news_items/2017/mar/ucsb_080317.shtml',
#    'ref': '8 tunnel junction LEDs'}],
#  'January': [{'caption': 'Multi-level metalization for high-density gallium nitride transistors on silicon',
#    'img': '2017/01/1.svg',
#    'url': 'http://www.semiconductor-today.com/news_items/2017/jan/cnu_060117.shtml',
#    'ref': '1 mutilevel metal HFETs'},
#   {'caption': 'Light transmission from co-integrated laser and modulator on silicon',
#    'img': '2017/01/2.jpg',
#    'url': 'http://www.semiconductor-today.com/news_items/2017/jan/uga_090117.shtml',
#    'ref': '2 tunable laser-modulator on silicon'},
#   {'caption': 'Back-reflector for gallium indium nitride arsenide solar cells',
#    'img': '2017/01/3.webp',
#    'url': 'http://www.semiconductor-today.com/news_items/2017/jan/tampere_110117.shtml',
#    'ref': '3 GaInNAs solar cells'},
#   {'caption': 'Fully vertical and quasi-vertical gallium nitride pn diodes on silicon',
#    'img': '2017/01/4.jpg',
#    'url': 'http://www.semiconductor-today.com/news_items/2017/jan/mit_160117.shtml',
#    'ref': '4 vertical GaN pn diodes on Si'},
#   {'caption': 'Ultra-thin-barrier III-nitride metal-insulator-semiconductor transistors',
#    'img': '2017/01/5.svg',
#    'url': 'http://www.semiconductor-today.com/news_items/2017/jan/cas_200117.shtml',
#    'ref': '5 utb HEMT'},
#   {'caption': 'Interface engineering for green indium gallium nitride laser diodes',
#    'img': '2017/01/6.webp',
#    'url': 'http://www.semiconductor-today.com/news_items/2017/jan/cas_230117.shtml',
#    'ref': '6 green laser diodes'},
#   {'caption': 'Increasing light output power from gallium nitride LEDs with p-trenches',
#    'img': '2017/01/7.jpg',
#    'url': 'http://www.semiconductor-today.com/news_items/2017/jan/snu_270117.shtml',
#    'ref': '7 p-trench GaN LEDs'},
#   {'caption': 'Gold-free vertical gallium nitride Schottky barrier diodes',
#    'img': '2017/01/8.jpg',
#    'url': 'http://www.semiconductor-today.com/news_items/2017/feb/sinano_010217.shtml',
#    'ref': '8 SBD on FS-GaN'}]}

# %%
put(j,'2017.json')
